# %%
pip install pillow      # 파이썬에서 사진 컨트롤
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (7.0.0)

# %%
pip install requests    # 웹 전송/수신
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.10)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg  # jpg 등 의 이미지 파일 다루는 모듈

# %%
img = mpimg.imread('igun.jpg')

plt.figure(figsize=(10,8))
plt.imshow(img)
plt.show()

# %%
import requests

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('igun.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files=files, headers=headers)

# %%
import json
parsed = json.loads(response.text)
print(json.dumps(parsed, indent=4, sort_keys = False, ensure_ascii=False))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 1000,
#             "height": 833
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 406,
#                 "y": 192,
#                 "width": 92,
#                 "height": 92
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 429,
#                     "y": 207
#                 },
#                 "rightEye": {
#                     "x": 469,
#                     "y": 215
#                 },
#                 "nose": {
#                     "x": 441,
#                     "y": 237
#                 },
#                 "leftMouth": {
#                     "x": 420,
#                     "y": 251
#                 },
#                 "rightMouth": {
#                     "x": 464,
#                     "y": 259
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 1.0
#             },
#             "age": {
#                 "value": "51~55",
#                 "confidence": 0.687049
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.864189
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.997605
#             }
#         },
#         {
#             "roi": {
#                 "x": 658,
#                 "y": 243,
#                 "width": 83,
#                 "height": 83
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 678,
#                     "y": 256
#                 },
#                 "rightEye": {
#                     "x": 714,
#                     "y": 264
#                 },
#                 "nose": {
#                     "x": 686,
#                     "y": 283
#                 },
#                 "leftMouth": {
#                     "x": 670,
#                     "y": 295
#                 },
#                 "rightMouth": {
#                     "x": 707,
#                     "y": 304
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999937
#             },
#             "age": {
#                 "value": "29~33",
#                 "confidence": 0.294579
#             },
#             "emotion": {
#                 "value": "laugh",
#                 "confidence": 0.634728
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.996551
#             }
#         },
#         {
#             "roi": {
#                 "x": 265,
#                 "y": 151,
#                 "width": 95,
#                 "height": 95
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 293,
#                     "y": 169
#                 },
#                 "rightEye": {
#                     "x": 333,
#                     "y": 178
#                 },
#                 "nose": {
#                     "x": 304,
#                     "y": 200
#                 },
#                 "leftMouth": {
#                     "x": 281,
#                     "y": 213
#                 },
#                 "rightMouth": {
#                     "x": 323,
#                     "y": 222
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.999992
#             },
#             "age": {
#                 "value": "31~35",
#                 "confidence": 0.9585
#             },
#             "emotion": {
#                 "value": "laugh",
#                 "confidence": 0.825593
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.998403
#             }
#         },
#         {
#             "roi": {
#                 "x": 536,
#                 "y": 245,
#                 "width": 95,
#                 "height": 95
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 561,
#                     "y": 267
#                 },
#                 "rightEye": {
#                     "x": 604,
#                     "y": 274
#                 },
#                 "nose": {
#                     "x": 584,
#                     "y": 298
#                 },
#                 "leftMouth": {
#                     "x": 557,
#                     "y": 313
#                 },
#                 "rightMouth": {
#                     "x": 601,
#                     "y": 319
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.972618
#             },
#             "age": {
#                 "value": "40~44",
#                 "confidence": 0.311933
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.988626
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.93292
#             }
#         }
#     ]
# }

# %% [markdown]
# ##### 간단한 문법 정리 #####

# %%
dict_sample = {'Name':'pinkwink', 'Age':'None', 'Class':['beginner','blog']}

# %%
dict_sample
# Out:
# {'Age': 'None', 'Class': ['beginner', 'blog'], 'Name': 'pinkwink'}

# %%
dict_sample.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict_sample.values()
# Out:
# dict_values(['pinkwink', 'None', ['beginner', 'blog']])

# %%
dict_sample.get('Name')
# Out:
# 'pinkwink'

# %%
dict_sample.get('Age')
# Out:
# 'None'

# %%
dict_sample.get('ABC')

# %%
customer = {
    'id':'0001',
    'name':'홍길동',
    'history': [
                {'date':'2019-03-01','log':True},
                {'date':'2019-03-02','log':False},
    ]
}

# %%
import json

json_test = json.dumps(customer, indent = 4, ensure_ascii=False)
            # json.dump 를 사용하여 json데이터 생성
print(json_test)
# Out:
# {
#     "id": "0001",
#     "name": "홍길동",
#     "history": [
#         {
#             "date": "2019-03-01",
#             "log": true
#         },
#         {
#             "date": "2019-03-02",
#             "log": false
#         }
#     ]
# }

# %%
import requests

client_id = "JtzyEv6hdzG2mhfewvFn"
client_secret = "b7VOpgnzec"

url = "https://openapi.naver.com/v1/vision/face"
files = {'image':open('igun.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret}

response = requests.post(url, files=files, headers=headers)

detect_result = json.loads(response.text)

# %%
detect_result.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
detect_result['faces']
# Out:
# [{'age': {'confidence': 0.687049, 'value': '51~55'},
#   'emotion': {'confidence': 0.864189, 'value': 'smile'},
#   'gender': {'confidence': 1.0, 'value': 'male'},
#   'landmark': {'leftEye': {'x': 429, 'y': 207},
#    'leftMouth': {'x': 420, 'y': 251},
#    'nose': {'x': 441, 'y': 237},
#    'rightEye': {'x': 469, 'y': 215},
#    'rightMouth': {'x': 464, 'y': 259}},
#   'pose': {'confidence': 0.997605, 'value': 'frontal_face'},
#   'roi': {'height': 92, 'width': 92, 'x': 406, 'y': 192}},
#  {'age': {'confidence': 0.294579, 'value': '29~33'},
#   'emotion': {'confidence': 0.634728, 'value': 'laugh'},
#   'gender': {'confidence': 0.999937, 'value': 'female'},
#   'landmark': {'leftEye': {'x': 678, 'y': 256},
#    'leftMouth': {'x': 670, 'y': 295},
#    'nose': {'x': 686, 'y': 283},
#    'rightEye': {'x': 714, 'y': 264},
#    'rightMouth': {'x': 707, 'y': 304}},
#   'pose': {'confidence': 0.996551, 'value': 'frontal_face'},
#   'roi': {'height': 83, 'width': 83, 'x': 658, 'y': 243}},
#  {'age': {'confidence': 0.9585, 'value': '31~35'},
#   'emotion': {'confidence': 0.825593, 'value': 'laugh'},
#   'gender': {'confidence': 0.999992, 'value': 'male'},
#   'landmark': {'leftEye': {'x': 293, 'y': 169},
#    'leftMouth': {'x': 281, 'y': 213},
#    'nose': {'x': 304, 'y': 200},
#    'rightEye': {'x': 333, 'y': 178},
#    'rightMouth': {'x': 323, 'y': 222}},
#   'pose': {'confidence': 0.998403, 'value': 'frontal_face'},
#   'roi': {'height': 95, 'width': 95, 'x': 265, 'y': 151}},
#  {'age': {'confidence': 0.311933, 'value': '40~44'},
#   'emotion': {'confidence': 0.988626, 'value': 'smile'},
#   'gender': {'confidence': 0.972618, 'value': 'male'},
#   'landmark': {'leftEye': {'x': 561, 'y': 267},
#    'leftMouth': {'x': 557, 'y': 313},
#    'nose': {'x': 584, 'y': 298},
#    'rightEye': {'x': 604, 'y': 274},
#    'rightMouth': {'x': 601, 'y': 319}},
#   'pose': {'confidence': 0.93292, 'value': 'frontal_face'},
#   'roi': {'height': 95, 'width': 95, 'x': 536, 'y': 245}}]

# %%
detect_result['faces'][0]
# Out:
# {'age': {'confidence': 0.687049, 'value': '51~55'},
#  'emotion': {'confidence': 0.864189, 'value': 'smile'},
#  'gender': {'confidence': 1.0, 'value': 'male'},
#  'landmark': {'leftEye': {'x': 429, 'y': 207},
#   'leftMouth': {'x': 420, 'y': 251},
#   'nose': {'x': 441, 'y': 237},
#   'rightEye': {'x': 469, 'y': 215},
#   'rightMouth': {'x': 464, 'y': 259}},
#  'pose': {'confidence': 0.997605, 'value': 'frontal_face'},
#  'roi': {'height': 92, 'width': 92, 'x': 406, 'y': 192}}

# %%
detect_result['faces'][0]['roi']
# Out:
# {'height': 92, 'width': 92, 'x': 406, 'y': 192}

# %%
detect_result['faces'][0]['gender']
# Out:
# {'confidence': 1.0, 'value': 'male'}

# %%
detect_result['faces'][0]['age']
# Out:
# {'confidence': 0.687049, 'value': '51~55'}

# %%
detect_result['faces'][0]['emotion']
# Out:
# {'confidence': 0.864189, 'value': 'smile'}

# %%
# x ,y , w , h = detect_result['faces'][0]['roi'].values()
# gender, gen_c = detect_result['faces'][0]['gender'].values()
# emotion, emotion_c = detect_result['faces'][0]['emotion'].values()
# age, age_c = detect_result['faces'][0]['age'].values()

# %%
# annotation = gender + ':' + str(gen_c) + '\n' + emotion + ':' + str(emotion_c) + '\n'+ age + ":"+str(age_c)

# %%
# print(annotation)
# Out:
# male:1.0
# smile:0.864189
# 51~55:0.687049

# %%
# import matplotlib.patches as patches

# img = mpimg.imread('igun.jpg')

# fig, ax = plt.subplots(figsize=(10,10))
# ax.imshow(img)
# rect_face = patches.Rectangle((x,y), w, h,
#                               linewidth=5,
#                               edgecolor= 'r',
#                               facecolor='none')
# ax.add_patch(rect_face)

# plt.text(10,400,annotation, wrap=True, fontsize = 17, color='white')
# plt.show()

# %%
import matplotlib.patches as patches

img = mpimg.imread('igun.jpg')

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(img)

for each in detect_result['faces']:
  x ,y , w , h = each['roi'].values()
  gender, gen_c = each['gender'].values()
  emotion, emotion_c = each['emotion'].values()
  age, age_c = each['age'].values()

  rect_face = patches.Rectangle((x,y), w, h,
                                linewidth=3,
                                edgecolor= 'r',
                                facecolor='none')
  ant_letter = gender + ', ' + emotion + ', ' + age
  plt.text(x, y+h+40, ant_letter, size = 12, color = 'blue')
  ax.add_patch(rect_face)

plt.show()
